# %% [markdown]
# <a href="https://colab.research.google.com/github/slagathorr/cvdb/blob/main/CVDB_with_DuckDB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# As a thought experiment, we thought we would see how easy or difficult it will be to take the [Open CVDB](https://github.com/wiz-sec/open-cvdb) files and load them into DuckDB to do some quick analysis. The source files are a series of YAML files ([located here](https://github.com/wiz-sec/open-cvdb/tree/main/vulnerabilities)) that we need to shoehorn into the database.
#
# Spoiler alert, turns out it's pretty easy.

# %% [markdown]
# # Setup
#
# This uses PyYAML, but it's already installed with Colab.
#
# This uses DuckDB, but it's already installed with Colab.

# %%
# Fetch the files.

# !rm -rf /my_computer
# !git clone https://github.com/wiz-sec/open-cvdb.git /my_computer
# !mkdir  /my_computer/vulnerabilities_json/
# Out:
# Cloning into '/my_computer'...
# remote: Enumerating objects: 2358, done.
# remote: Counting objects: 100% (319/319), done.
# remote: Compressing objects: 100% (242/242), done.
# remote: Total 2358 (delta 148), reused 217 (delta 74), pack-reused 2039
# Receiving objects: 100% (2358/2358), 35.29 MiB | 35.96 MiB/s, done.
# Resolving deltas: 100% (1403/1403), done.

# %%
# Hit the library.

import yaml
import json
import os
from google.colab import data_table

data_table.enable_dataframe_formatter()

# %% [markdown]
# Let's process the files and convert them to JSON.

# %%
# Iterate through the YAML files, read them into a native Python data type, and write out JSON.

for filename in os.listdir('/my_computer/vulnerabilities/'):
  filename_yaml = "/my_computer/vulnerabilities/" + filename
  print("Starting: ", filename)
  filename_json = "/my_computer/vulnerabilities_json/" + filename.replace("yaml", "json")
  with open(filename_yaml, 'r') as yaml_in, open(filename_json, "w") as json_out:
    yaml_object = yaml.safe_load(yaml_in) # yaml_object will be a list or a dict
    json.dump(yaml_object, json_out)
  print("Wrote: ", filename_json)
# Out:
# Starting:  gke-autopilot-allowlist.yaml
# Wrote:  /my_computer/vulnerabilities_json/gke-autopilot-allowlist.json
# Starting:  privilege-identification-cloudtrail.yaml
# Wrote:  /my_computer/vulnerabilities_json/privilege-identification-cloudtrail.json
# Starting:  aws-xss-console.yaml
# Wrote:  /my_computer/vulnerabilities_json/aws-xss-console.json
# Starting:  aws-rds-no-ssl-tls.yaml
# Wrote:  /my_computer/vulnerabilities_json/aws-rds-no-ssl-tls.json
# Starting:  api-mgmt-ssrf-path-traversal.yaml
# Wrote:  /my_computer/vulnerabilities_json/api-mgmt-ssrf-path-traversal.json
# Starting:  cap-net-raw-metadata-mitm.yaml
# Wrote:  /my_computer/vulnerabilities_json/cap-net-raw-metadata-mitm.json
# Starting:  aws-fall-2020-soc2.yaml
# Wrote:  /my_computer/vulnerabilities_json/aws-fall-2020-soc2.json
# Starting:  iam-policies-bypass-overprivileged.yaml
# Wrote:  /my_computer/vulnerabilities_json/iam-policies-bypass-overprivileged.json
# Starting:  aws-waf-sql-injection.yaml
# Wrote:  /my_computer/vulnerabilities_json/aws-waf-sql-injection.json
# Starting:  cve-2021-38112.yaml
# Wrote:  /my_computer/vulnerabilities_json/cve-2021-38112.json
# Starting:  cognito-user-group-spoofing.yaml
# Wrote:  /my_computer/vulnerabilities_json/cognito-user-group-spoofing.json
# Starting:  aws-fall-2021-soc2.yaml
# Wrote:  /my_computer/vulnerabilities_json/aws-fall-2021-soc2.json
# Starting:  eltima-cloud-desktop-lpe.yaml
# Wrote:  /my_computer/vulnerabilities_json/eltima-cloud-desktop-lpe.json
# Starting:  azure-b2c-crypto-flaw.yaml
# Wrote:  /my_computer/vulnerabilities_json/azure-b2c-crypto-flaw.json
# Starting:  ssrf-in-google-cloud-monitoring.yaml
# Wrote:  /my_computer/vulnerabilities_json/ssrf-in-google-cloud-monitoring.json
# Starting:  aws-package-backfill.yaml
# Wrote:  /my_computer/vulnerabilities_json/aws-package-backfill.json
# Starting:  s3-crypto-sdk.yaml
# Wrote:  /my_computer/vulnerabilities_json/s3-crypto-sdk.json
# Starting:  superglue.yaml
# Wrote:  /my_computer/vulnerabilities_json/superglue.json
# Starting:  ec2-console-xss.yaml
# Wrote:  /my_computer/vulnerabilities_json/ec2-console-xss.json
# Starting:  azure-func-escape.yaml
# Wrote:  /my_computer/vulnerabilities_json/azure-func-escape.json
# Starting:  lightsail-keys-logged.yaml
# Wrote:  /my_computer/vulnerabilities_json/lightsail-keys-logged.json
# Starting:  elb-cache-http-smuggling.yaml
# Wrote:  /my_computer/vulnerabilities_json/elb-cache-http-smuggling.json
# Starting:  extrareplica.yaml
# Wrote:  /my_computer/vulnerabilities_json/extrareplica.json
# Starting:  cve-2021-27075.yaml
# Wrote:  /my_computer/vulnerabilities_json/cve-2021-27075.json
# Starting:  cve-2022-29527.yaml
# Wrote:  /my_computer/vulnerabilities_json/cve-2022-29527.json
# Starting:  bastion-container-reg-xss.yaml
# Wrote:  /my_computer/vulnerabilities_json/bastion-container-reg-xss.json
# Starting:  app-runner-vpc-connectors.yaml
# Wrote:  /my_computer/vulnerabilities_json/app-runner-vpc-connectors.json
# Starting:  cve-2022-37968.yaml
# Wrote:  /my_computer/vulnerabilities_json/cve-2022-37968.json
# Starting:  aws-java-sdk-xxe.yaml
# Wrote:  /my_computer/vulnerabilities_json/aws-java-sdk-xxe.json
# Starting:  azure-info-disclosure.yaml
# Wrote:  /my_computer/vulnerabilities_json/azure-info-disclosure.json
# Starting:  emojideploy.yaml
# Wrote:  /my_computer/vulnerabilities_json/emojideploy.json
# Starting:  cosmiss.yaml
# Wrote:  /my_computer/vulnerabilities_json/cosmiss.json
# Starting:  aws-s3-recon-account-id-of-bucket.yaml
# Wrote:  /my_computer/vulnerabilities_json/aws-s3-recon-account-id-of-bucket.json
# Starting:  azure-mgmt-api-rce.yaml
# Wrote:  /my_computer/vulnerabilities_json/azure-mgmt-api-rce.json
# Starting:  overprivileged-aws-support-iam.yaml
# Wrote:  /my_computer/vulnerabilities_json/overprivileged-aws-support-iam.json
# Starting:  notlegit.yaml
# Wrote:  /my_computer/vulnerabilities_json/notlegit.json
# Starting:  cve-2023-21777.yaml
# Wrote:  /my_computer/vulnerabilities_json/cve-2023-21777.json
# Starting:  aws-iamadmin-cloudtrail-bypass.yaml
# Wrote:  /my_computer/vulnerabilities_json/aws-iamadmin-cloudtrail-bypass.json
# Starting:  azure-front-door-desync.yaml
# Wrote:  /my_computer/vulnerabilities_json/azure-front-door-desync.json
# Starting:  gcp-cloudshell-command-injection.yaml
# Wrote:  /my_computer/vulnerabilities_json/gcp-cloudshell-command-injection.json
# Starting:  attachme.yaml
# Wrote:  /my_computer/vulnerabilities_json/attachme.json
# Starting:  s3-bucket-tagging-not-restricted.yaml
# Wrote:  /my_computer/vulnerabilities_json/s3-bucket-tagging-not-restricted.json
# Starting:  cve-2019-1372.yaml
# Wrote:  /my_computer/vulnerabilities_json/cve-2019-1372.json
# Starting:  azure-functions-eop.yaml
# Wrote:  /my_computer/vulnerabilities_json/azure-functions-eop.json
# Starting:  cloudformation-dos.yaml
# Wrote:  /my_computer/vulnerabilities_json/cloudformation-dos.json
# Starting:  gcp-iap-bypass.yaml
# Wrote:  /my_computer/vulnerabilities_json/gcp-iap-bypass.json
# Starting:  cloudformer-review.yaml
# Wrote:  /my_computer/vulnerabilities_json/cloudformer-review.json
# Starting:  aws-rds-local-file-read.yaml
# Wrote:  /my_computer/vulnerabilities_json/aws-rds-local-file-read.json
# Starting:  gcp-os-login-pe.yaml
# Wrote:  /my_computer/vulnerabilities_json/gcp-os-login-pe.json
# Starting:  cve-2022-30137.yaml
# Wrote:  /my_computer/vulnerabilities_json/cve-2022-30137.json
# Starting:  vpc-hosted-zones-unauditable.yaml
# Wrote:  /my_computer/vulnerabilities_json/vpc-hosted-zones-unauditable.json
# Starting:  data_gateway_rce.yaml
# Wrote:  /my_computer/vulnerabilities_json/data_gateway_rce.json
# Starting:  cloudsql-escape.yaml
# Wrote:  /my_computer/vulnerabilities_json/cloudsql-escape.json
# Starting:  log-analytics-role-privesc.yaml
# Wrote:  /my_computer/vulnerabilities_json/log-analytics-role-privesc.json
# Starting:  aws-cloudshell-terminal-escape.yaml
# Wrote:  /my_computer/vulnerabilities_json/aws-cloudshell-terminal-escape.json
# Starting:  sagemaker-jupyter-csrf.yaml
# Wrote:  /my_computer/vulnerabilities_json/sagemaker-jupyter-csrf.json
# Starting:  aws-appsync-confused-deputy.yaml
# Wrote:  /my_computer/vulnerabilities_json/aws-appsync-confused-deputy.json
# Starting:  azure-pipeline-rce.yaml
# Wrote:  /my_computer/vulnerabilities_json/azure-pipeline-rce.json
# Starting:  breakingformation.yaml
# Wrote:  /my_computer/vulnerabilities_json/breakingformation.json
# Starting:  aws-sigv1-insecure.yaml
# Wrote:  /my_computer/vulnerabilities_json/aws-sigv1-insecure.json
# Starting:  aad-seamless-sso-log-bypass.yaml
# Wrote:  /my_computer/vulnerabilities_json/aad-seamless-sso-log-bypass.json
# Starting:  s3-replicator-cloudtrail.yaml
# Wrote:  /my_computer/vulnerabilities_json/s3-replicator-cloudtrail.json
# Starting:  gcp-org-policy-exfiltrate-data.yaml
# Wrote:  /my_computer/vulnerabilities_json/gcp-org-policy-exfiltrate-data.json
# Starting:  codebuild-data-exfil.yaml
# Wrote:  /my_computer/vulnerabilities_json/codebuild-data-exfil.json
# Starting:  synlapse.yaml
# Wrote:  /my_computer/vulnerabilities_json/synlapse.json
# Starting:  aws-api-gw-smuggling.yaml
# Wrote:  /my_computer/vulnerabilities_json/aws-api-gw-smuggling.json
# Starting:  resource-policy-confused-deputy.yaml
# Wrote:  /my_computer/vulnerabilities_json/resource-policy-confused-deputy.json
# Starting:  noauth.yaml
# Wrote:  /my_computer/vulnerabilities_json/noauth.json
# Starting:  gcp-org-policies-bypass.yaml
# Wrote:  /my_computer/vulnerabilities_json/gcp-org-policies-bypass.json
# Starting:  azure-cloud-shell-and-container-instance-lpe.yaml
# Wrote:  /my_computer/vulnerabilities_json/azure-cloud-shell-and-container-instance-lpe.json
# Starting:  ami-recoverable-files.yaml
# Wrote:  /my_computer/vulnerabilities_json/ami-recoverable-files.json
# Starting:  dhcp-abuse-code-exec.yaml
# Wrote:  /my_computer/vulnerabilities_json/dhcp-abuse-code-exec.json
# Starting:  omigod.yaml
# Wrote:  /my_computer/vulnerabilities_json/omigod.json
# Starting:  azure-cloudshell-injection.yaml
# Wrote:  /my_computer/vulnerabilities_json/azure-cloudshell-injection.json
# Starting:  azure-devops-dangling-domain.yaml
# Wrote:  /my_computer/vulnerabilities_json/azure-devops-dangling-domain.json
# Starting:  guardduty-cloudtrail-bypass.yaml
# Wrote:  /my_computer/vulnerabilities_json/guardduty-cloudtrail-bypass.json
# Starting:  gcp-iam-pe-multiple-services.yaml
# Wrote:  /my_computer/vulnerabilities_json/gcp-iam-pe-multiple-services.json
# Starting:  aws-console-rate-limit-bypass.yaml
# Wrote:  /my_computer/vulnerabilities_json/aws-console-rate-limit-bypass.json
# Starting:  cve-2023-23383.yaml
# Wrote:  /my_computer/vulnerabilities_json/cve-2023-23383.json
# Starting:  cloud-func-gke-bypass.yaml
# Wrote:  /my_computer/vulnerabilities_json/cloud-func-gke-bypass.json
# Starting:  acsessed.yaml
# Wrote:  /my_computer/vulnerabilities_json/acsessed.json
# Starting:  iam-managed-policies-lack-controls.yaml
# Wrote:  /my_computer/vulnerabilities_json/iam-managed-policies-lack-controls.json
# Starting:  cve-2022-2385.yaml
# Wrote:  /my_computer/vulnerabilities_json/cve-2022-2385.json
# Starting:  alb-http-smuggling.yaml
# Wrote:  /my_computer/vulnerabilities_json/alb-http-smuggling.json
# Starting:  azure-subdomain-takeover.yaml
# Wrote:  /my_computer/vulnerabilities_json/azure-subdomain-takeover.json
# Starting:  synapse-spark-lpe.yaml
# Wrote:  /my_computer/vulnerabilities_json/synapse-spark-lpe.json
# Starting:  log4shell-hotpatch.yaml
# Wrote:  /my_computer/vulnerabilities_json/log4shell-hotpatch.json
# Starting:  azure_multiple_ssrf.yaml
# Wrote:  /my_computer/vulnerabilities_json/azure_multiple_ssrf.json
# Starting:  cloudformation_cred_leak.yaml
# Wrote:  /my_computer/vulnerabilities_json/cloudformation_cred_leak.json
# Starting:  encryption-sdk-issues.yaml
# Wrote:  /my_computer/vulnerabilities_json/encryption-sdk-issues.json
# Starting:  cve-2022-29149.yaml
# Wrote:  /my_computer/vulnerabilities_json/cve-2022-29149.json
# Starting:  synapse-pwnalytics.yaml
# Wrote:  /my_computer/vulnerabilities_json/synapse-pwnalytics.json
# Starting:  aws-codestar-privilege-escalation.yaml
# Wrote:  /my_computer/vulnerabilities_json/aws-codestar-privilege-escalation.json
# Starting:  autowarp.yaml
# Wrote:  /my_computer/vulnerabilities_json/autowarp.json
# Starting:  terms-conditions-customer-data.yaml
# Wrote:  /my_computer/vulnerabilities_json/terms-conditions-customer-data.json
# Starting:  cve-2022-35829.yaml
# Wrote:  /my_computer/vulnerabilities_json/cve-2022-35829.json
# Starting:  gcp-cloudshell-xss-csrf.yaml
# Wrote:  /my_computer/vulnerabilities_json/gcp-cloudshell-xss-csrf.json
# Starting:  apiary-ssrf.yaml
# Wrote:  /my_computer/vulnerabilities_json/apiary-ssrf.json
# Starting:  public-ecr-undocumented-api.yaml
# Wrote:  /my_computer/vulnerabilities_json/public-ecr-undocumented-api.json
# Starting:  azurescape.yaml
# Wrote:  /my_computer/vulnerabilities_json/azurescape.json
# Starting:  azure-waf-bypass.yaml
# Wrote:  /my_computer/vulnerabilities_json/azure-waf-bypass.json
# Starting:  lambda-cloudwatch-timing-attack.yaml
# Wrote:  /my_computer/vulnerabilities_json/lambda-cloudwatch-timing-attack.json
# Starting:  dependency-confusion-in-aws-codeartifact.yaml
# Wrote:  /my_computer/vulnerabilities_json/dependency-confusion-in-aws-codeartifact.json
# Starting:  asset-key-thief.yaml
# Wrote:  /my_computer/vulnerabilities_json/asset-key-thief.json
# Starting:  iam-multiple-mfa.yaml
# Wrote:  /my_computer/vulnerabilities_json/iam-multiple-mfa.json
# Starting:  ai-hub-jupyter-csrf.yaml
# Wrote:  /my_computer/vulnerabilities_json/ai-hub-jupyter-csrf.json
# Starting:  gcp-cloushell-bugs.yaml
# Wrote:  /my_computer/vulnerabilities_json/gcp-cloushell-bugs.json
# Starting:  cve-2018-15869.yaml
# Wrote:  /my_computer/vulnerabilities_json/cve-2018-15869.json
# Starting:  gcp-default-compute-account.yaml
# Wrote:  /my_computer/vulnerabilities_json/gcp-default-compute-account.json
# Starting:  admin-azure-rh-update-infrastructure.yaml
# Wrote:  /my_computer/vulnerabilities_json/admin-azure-rh-update-infrastructure.json
# Starting:  gce_ssh_key_injection.yaml
# Wrote:  /my_computer/vulnerabilities_json/gce_ssh_key_injection.json
# Starting:  lake_admin_override.yaml
# Wrote:  /my_computer/vulnerabilities_json/lake_admin_override.json
# Starting:  gke-gvisor-sandbox-escape.yaml
# Wrote:  /my_computer/vulnerabilities_json/gke-gvisor-sandbox-escape.json
# Starting:  azure-logic-app-contributor-escalation-to-root-owner.yaml
# Wrote:  /my_computer/vulnerabilities_json/azure-logic-app-contributor-escalation-to-root-owner.json
# Starting:  aws-data-post.yaml
# Wrote:  /my_computer/vulnerabilities_json/aws-data-post.json
# Starting:  mwaa-leaky-logs.yaml
# Wrote:  /my_computer/vulnerabilities_json/mwaa-leaky-logs.json
# Starting:  chaosdb.yaml
# Wrote:  /my_computer/vulnerabilities_json/chaosdb.json
# Starting:  rce-in-cloud-dm.yaml
# Wrote:  /my_computer/vulnerabilities_json/rce-in-cloud-dm.json
# Starting:  brokensesame.yaml
# Wrote:  /my_computer/vulnerabilities_json/brokensesame.json
# Starting:  hellskeychain.yaml
# Wrote:  /my_computer/vulnerabilities_json/hellskeychain.json
# Starting:  ghosttoken.yaml
# Wrote:  /my_computer/vulnerabilities_json/ghosttoken.json
# Starting:  power-platform-info-leak.yaml
# Wrote:  /my_computer/vulnerabilities_json/power-platform-info-leak.json
# Starting:  app-runner-observability.yaml
# Wrote:  /my_computer/vulnerabilities_json/app-runner-observability.json
# Starting:  badbuild.yaml
# Wrote:  /my_computer/vulnerabilities_json/badbuild.json
# Starting:  aws-imds-credential-exfiltration.yaml
# Wrote:  /my_computer/vulnerabilities_json/aws-imds-credential-exfiltration.json
# Starting:  gcp-8kb-bypass.yaml
# Wrote:  /my_computer/vulnerabilities_json/gcp-8kb-bypass.json
# Starting:  aws-directory-service-passrole.yaml
# Wrote:  /my_computer/vulnerabilities_json/aws-directory-service-passrole.json
# Starting:  aws-route-table-modify.yaml
# Wrote:  /my_computer/vulnerabilities_json/aws-route-table-modify.json
# Starting:  aws-codebuild-ecr-iam-vuln.yaml
# Wrote:  /my_computer/vulnerabilities_json/aws-codebuild-ecr-iam-vuln.json
# Starting:  cloudsql-privesc.yaml
# Wrote:  /my_computer/vulnerabilities_json/cloudsql-privesc.json
# Starting:  bluebleed.yaml
# Wrote:  /my_computer/vulnerabilities_json/bluebleed.json
# Starting:  aws-auth-multiple-issues.yaml
# Wrote:  /my_computer/vulnerabilities_json/aws-auth-multiple-issues.json
# Starting:  dataflow-rce-jmx.yaml
# Wrote:  /my_computer/vulnerabilities_json/dataflow-rce-jmx.json
# Starting:  cve-2022-25165.yaml
# Wrote:  /my_computer/vulnerabilities_json/cve-2022-25165.json
# Starting:  assumerole-confused-deputy.yaml
# Wrote:  /my_computer/vulnerabilities_json/assumerole-confused-deputy.json
# Starting:  aws-service-catalog-cloudtrail-bypass.yaml
# Wrote:  /my_computer/vulnerabilities_json/aws-service-catalog-cloudtrail-bypass.json
# Starting:  azure-cloudshell-terminal-escape.yaml
# Wrote:  /my_computer/vulnerabilities_json/azure-cloudshell-terminal-escape.json
# Starting:  cve-2022-33675.yaml
# Wrote:  /my_computer/vulnerabilities_json/cve-2022-33675.json
# Starting:  cve-2021-42306.yaml
# Wrote:  /my_computer/vulnerabilities_json/cve-2021-42306.json
# Starting:  aws-control-tower-lack-of-cloudtrail-logging.yaml
# Wrote:  /my_computer/vulnerabilities_json/aws-control-tower-lack-of-cloudtrail-logging.json

# %% [markdown]
# # DuckDB Time!
#
# Let's first take a look at a file and see what they look like.

# %%
# !cat /my_computer/vulnerabilities/autowarp.yaml
# Out:
# title: AutoWarp
# slug: autowarp
# cves: null
# affectedPlatforms:
# - Azure
# affectedServices:
# - Automation Service
# image: https://images.unsplash.com/photo-1651491602333-fea83f1d9107?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=1170&q=80
# severity: Critical
# piercingIndexVector: {version: 1.5, A1: 20, A2: 1.21, A7: 1.1, A8: 1.1}
# discoveredBy:
#   name: Yanir Tsarimi
#   org: Orca Security
#   domain: https://orca.security/
#   twitter: null
# publishedAt: 2022/03/07
# disclosedAt: 2021/12/06
# exploitabilityPeriod: null
# knownITWExploitation: false
# summary: |
#   An exposed endpoint in the Azure Automation Service allowed to steal Azure
#   API credentials from other customers
# manualRemediation: |
#   None required. As a general practice, use the least-privilege
#   principle, including on managed identities assigned to automation accounts. While
#   this would not have prevented the leakage of API credentials, it would have reduced
#   the blast radius.
# detectionMethods: null
# contributor: https://github.com/christophetd
# references:
# - https://orca.security/resources/blog/autowarp-microsoft-azure-automation-service-vulnerability/

# %% [markdown]
# ## Let's fetch a duck!

# %% [markdown]
# ## Create and load table
#
# Load up a DuckDB instance, and start digging.
#
# We are manually defining a schema because while the structure is consistent, the data values are necessarily not. As an example, there are instances where the `knownITWExploitation` field is set to a `STRING` of "No" and others where it's a `BOOL` of `false`. The auto detect functions would set this as a `BOOL` and error out when it hit strings. There are other data types like that as well.

# %%
import duckdb
conn = duckdb.connect()

conn.execute("""
CREATE OR REPLACE TABLE vulns AS (
  SELECT * FROM READ_JSON_AUTO('/my_computer/vulnerabilities_json/*.json', columns={
    title:  'VARCHAR',
    slug:   'VARCHAR',
    cves:   'VARCHAR[]',
    affectedPlatforms:  'VARCHAR[]',
    affectedServices:   'VARCHAR[]',
    image:  'VARCHAR',
    severity:           'VARCHAR',
    discoveredBy:       'STRUCT(name VARCHAR, org VARCHAR, domain VARCHAR, twitter JSON)',
    disclosedAt:        'DATE',
    publishedAt:        'DATE',
    exploitabilityPeriod:   'JSON',
    knownITWExploitation:   'VARCHAR',
    summary:            'VARCHAR',
    manualRemediation:  'VARCHAR',
    detectionMethods:   'JSON',
    contributor:        'VARCHAR',
    "references":       'VARCHAR[]',
    piercingIndexVector:  'STRUCT(version DOUBLE, A1 BIGINT, A2 DOUBLE, A7 DOUBLE, A8 DOUBLE)'
    }, ignore_errors=true
                        ));
""")

conn.execute("""
DESCRIBE vulns;
""").fetchdf()
# Out:
#              column_name                                        column_type  \
# 0                  title                                            VARCHAR
# 1                   slug                                            VARCHAR
# 2                   cves                                          VARCHAR[]
# 3      affectedPlatforms                                          VARCHAR[]
# 4       affectedServices                                          VARCHAR[]
# 5                  image                                            VARCHAR
# 6               severity                                            VARCHAR
# 7           discoveredBy  STRUCT("name" VARCHAR, org VARCHAR, "domain" V...
# 8            disclosedAt                                               DATE
# 9            publishedAt                                               DATE
# 10  exploitabilityPeriod                                               JSON
# 11  knownITWExploitation                                            VARCHAR
# 12               summary                                            VARCHAR
# 13     manualRemediation                                            VARCHAR
# 14      detectionMethods                                               JSON
# 15           contributor                                            VARCHAR
# 16            references                                          VARCHAR[]
# 17   piercingIndexVector  STRUCT("version" DOUBLE, A1 BIGINT, A2 DOUBLE,...
#
#    null  key default  extra
# 0   YES  NaN     NaN    NaN
# 1   YES  NaN     NaN    NaN
# 2   YES  NaN     NaN    NaN
# 3   YES  NaN     NaN    NaN
# 4   YES  NaN     NaN    NaN
# 5   YES  NaN     NaN    NaN
# 6   YES  NaN     NaN    NaN
# 7   YES  NaN     NaN    NaN
# 8   YES  NaN     NaN    NaN
# 9   YES  NaN     NaN    NaN
# 10  YES  NaN     NaN    NaN
# 11  YES  NaN     NaN    NaN
# 12  YES  NaN     NaN    NaN
# 13  YES  NaN     NaN    NaN
# 14  YES  NaN     NaN    NaN
# 15  YES  NaN     NaN    NaN
# 16  YES  NaN     NaN    NaN
# 17  YES  NaN     NaN    NaN

# %% [markdown]
# ## Verify

# %%
# Let's see the data.

conn.execute("SELECT * FROM vulns LIMIT 3").fetchdf()
# Out:
#                                                title  \
# 0  AWS uploaded sensitive data to public GitHub b...
# 1       Dataflow RCE via unauthenticated JMX service
# 2    Overprivileged CodeBuild default ECR IAM policy
#
#                          slug cves affectedPlatforms  \
# 0               aws-data-post  NaN             [AWS]
# 1            dataflow-rce-jmx  NaN             [GCP]
# 2  aws-codebuild-ecr-iam-vuln  NaN             [AWS]
#
#            affectedServices  \
# 0                       NaN
# 1                [Dataflow]
# 2  [AWS CodeBuild, AWS ECR]
#
#                                                image severity  \
# 0  https://images.unsplash.com/photo-158963038814...      NaN
# 1  https://raw.githubusercontent.com/wiz-sec/open...      Low
# 2  https://raw.githubusercontent.com/wiz-sec/open...   medium
#
#                                         discoveredBy disclosedAt publishedAt  \
# 0  {'name': None, 'org': 'Upguard', 'domain': 'ht...  2020-01-23  2020-01-23
# 1  {'name': 'Mike Brancato', 'org': None, 'domain...  2021-03-05  2021-12-28
# 2  {'name': 'Will Deane', 'org': 'ASX Consulting'...  2022-07-04  2023-02-25
#
#     exploitabilityPeriod knownITWExploitation  \
# 0                    NaN                  NaN
# 1                    NaN                false
# 2  "Until July 26, 2022"                  NaN
#
#                                              summary  \
# 0  An AWS employee pushed sensitive data to a pub...
# 1  Dataflow worker nodes ran an unauthenticated J...
# 2  For AWS CodeBuild, when using a custom contain...
#
#                                    manualRemediation detectionMethods  \
# 0                                    None required\n              NaN
# 1                                    None required\n              NaN
# 2  For any CodeBuild projects created before July...              NaN
#
#                      contributor  \
# 0  https://github.com/0xdabbad00
# 1   https://github.com/korniko98
# 2   https://github.com/willdeane
#
#                                           references  \
# 0  [https://www.upguard.com/breaches/identity-and...
# 1  [https://mbrancato.github.io/2021/12/28/rce-da...
# 2  [https://www.asxconsulting.co.uk/blog/codebuild/]
#
#                                  piercingIndexVector
# 0                                                NaN
# 1                                                NaN
# 2  {'version': 1.5, 'A1': None, 'A2': None, 'A7':...

# %%
# Quick verification to see if the previous YAML (autowarp) we looked at matches.

conn.execute("""
SELECT * FROM vulns
WHERE title = 'AutoWarp';
""").fetchdf()
# Out:
#       title      slug cves affectedPlatforms      affectedServices  \
# 0  AutoWarp  autowarp  NaN           [Azure]  [Automation Service]
#
#                                                image  severity  \
# 0  https://images.unsplash.com/photo-165149160233...  Critical
#
#                                         discoveredBy disclosedAt publishedAt  \
# 0  {'name': 'Yanir Tsarimi', 'org': 'Orca Securit...  2021-12-06  2022-03-07
#
#   exploitabilityPeriod knownITWExploitation  \
# 0                  NaN                false
#
#                                              summary  \
# 0  An exposed endpoint in the Azure Automation Se...
#
#                                    manualRemediation detectionMethods  \
# 0  None required. As a general practice, use the ...              NaN
#
#                        contributor  \
# 0  https://github.com/christophetd
#
#                                           references  \
# 0  [https://orca.security/resources/blog/autowarp...
#
#                                  piercingIndexVector
# 0  {'version': 1.5, 'A1': 20, 'A2': 1.21, 'A7': 1...

# %% [markdown]
# # Analysis Time!
#
# It looks like it works! Let's ask some questions.

# %% [markdown]
# ## How many vulnerabilities were disclosed per month?

# %%
# How many vulnerabilities were disclosed per month?

results=conn.execute("""
SELECT
  count(*) AS disclosure_count,
  STRFTIME(DATE_TRUNC('month',disclosedAt),'%B %Y') AS month,
  DATE_TRUNC('month', disclosedAt) AS month_datetime
  FROM vulns
  GROUP BY month_datetime
  ORDER BY month_datetime asc;
""").fetchdf()

results.plot(x="month", y="disclosure_count", kind="bar", figsize=(10, 5))
# Out:
# <Axes: xlabel='month'>

# %% [markdown]
# ## Are there really disclosures with no disclosure times?
#
# At the time of writing, we are finding that there are entires of `nan` on our histogram. Which makes us wonder, are there really disclosures that don't have time associated with them?
#
# ![Screenshot 2023-09-29 2.17.52 PM.png](data:image/png;base64,...)
#
# Let's see what the data actually looks like.

# %%
conn.execute("SELECT * FROM vulns WHERE disclosedat IS NULL").fetchdf()
# Out:
#                                                title  \
# 0            Signature version 1 (SigV1) is insecure
# 1                         AWS Java SDK XXE injection
# 2      GCP Default compute account is project Editor
# 3  Azure App Service on Azure Stack Hub privilege...
# 4                   GCP Cloudshell XSS and CSRF bugs
# 5                    SSRF in Google Cloud Monitoring
# 6                                          Bad.Build
#
#                               slug cves affectedPlatforms  \
# 0               aws-sigv1-insecure  NaN             [AWS]
# 1                 aws-java-sdk-xxe  NaN             [AWS]
# 2      gcp-default-compute-account  NaN             [GCP]
# 3                   cve-2023-21777  NaN           [Azure]
# 4          gcp-cloudshell-xss-csrf  NaN             [GCP]
# 5  ssrf-in-google-cloud-monitoring  NaN             [GCP]
# 6                         badbuild  NaN             [GCP]
#
#                          affectedServices  \
# 0                                     NaN
# 1                              [Java SDK]
# 2                                     NaN
# 3  [Azure App Service on Azure Stack Hub]
# 4                        [GCP Cloudshell]
# 5               [Google Cloud Monitoring]
# 6                           [Cloud Build]
#
#                                                image severity  \
# 0  https://c4.wallpaperflare.com/wallpaper/600/33...   Medium
# 1  https://raw.githubusercontent.com/wiz-sec/open...      Low
# 2  https://assets.website-files.com/6207f5adfd8e6...   Medium
# 3  https://raw.githubusercontent.com/wiz-sec/open...   Medium
# 4  https://raw.githubusercontent.com/wiz-sec/open...   Medium
# 5  https://images.unsplash.com/photo-159085602982...   Medium
# 6  https://raw.githubusercontent.com/wiz-sec/open...      Low
#
#                                         discoveredBy disclosedAt publishedAt  \
# 0  {'name': 'Colin Percival', 'org': None, 'domai...         NaT  2008-12-18
# 1  {'name': 'Alex Brasetvik', 'org': None, 'domai...         NaT  2017-10-10
# 2                                                NaN         NaT  2020-11-22
# 3  {'name': 'Ruslan Sayfiev, Denis Faiustov', 'or...         NaT  2023-02-14
# 4  {'name': 'Obmi', 'org': None, 'domain': 'https...         NaT  2019-12-15
# 5  {'name': 'David Nechuta', 'org': None, 'domain...         NaT  2020-11-12
# 6  {'name': 'Roi Nisimi', 'org': 'Orca Security',...         NaT  2023-07-18
#
#           exploitabilityPeriod knownITWExploitation  \
# 0  "until December 18th, 2008"                false
# 1                          NaN                false
# 2  "Since the creation of GCP"                false
# 3                          NaN                false
# 4                          NaN                false
# 5                          NaN                  NaN
# 6                          NaN                false
#
#                                              summary  \
# 0  When making authenticated API requests to AWS,...
# 1  The AWS Java SDK was vulnerable to XML externa...
# 2  When the compute API is enabled on a GCP Proje...
# 3  A privilege escalation vulnerability was disco...
# 4  GCP Cloudshell has been affected by various XS...
# 5  An SSRF bug in Google Cloud Monitoring's uptim...
# 6  An information disclosure vulnerability in the...
#
#                                    manualRemediation detectionMethods  \
# 0  None required, SigV1 is deprecated at this poi...              NaN
# 1                                    None required\n              NaN
# 2  Remove these permissions, it can be done via a...              NaN
# 3  Users of Azure App Service on Azure Stack Hub ...              NaN
# 4                                             null\n              NaN
# 5                                    None required\n              NaN
# 6                                    None required\n              NaN
#
#                        contributor  \
# 0       https://github.com/ramimac
# 1     https://github.com/korniko98
# 2  https://github.com/louisdurufle
# 3         https://github.com/mer-b
# 4         https://github.com/mer-b
# 5    https://github.com/0xdabbad00
# 6     https://github.com/korniko98
#
#                                           references piercingIndexVector
# 0  [http://www.daemonology.net/blog/2008-12-18-AW...                 NaN
# 1  [https://github.com/aws/aws-sdk-java/commit/08...                 NaN
# 2  [https://cloud.google.com/resource-manager/doc...                 NaN
# 3  [https://msrc.microsoft.com/update-guide/en-US...                 NaN
# 4  [https://obmiblog.blogspot.com/2022/12/gcp-202...                 NaN
# 5  [https://nechudav.blogspot.com/2020/11/31k-ssr...                 NaN
# 6  [https://cloud.google.com/build/docs/security-...                 NaN

# %% [markdown]
# Here we find that there are indeed instances where that is the case. On a side note, we also see that the `exploitabilityPeriod` field is also very much free form, which can make analysis of it somewhat of a challenge.
#
# ![Screenshot 2023-09-29 2.25.59 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## How many vulnerabilities were published per month?
#
# After chatting with a friend who knows security things more than I do, it looks like the publish date is going to be the one we really want to look at, and the data itself should be more complete. Let's try this one.

# %%
# How many vulnerabilities were published per month?

results=conn.execute("""
SELECT
  count(*) AS publish_count,
  STRFTIME(DATE_TRUNC('month',publishedAt),'%B %Y') AS month,
  DATE_TRUNC('month', publishedAt) AS month_datetime
  FROM vulns
  GROUP BY month_datetime
  ORDER BY month_datetime asc;
""").fetchdf()

results.plot(x="month", y="publish_count", kind="bar", figsize=(10, 5))
# Out:
# <Axes: xlabel='month'>

# %% [markdown]
# ## What cloud platforms have the most vulnerabilities?

# %%
results=conn.execute("""
  WITH unnested_platforms AS (
    SELECT UNNEST(affectedPlatforms) AS cloud_platform
    FROM vulns)
  SELECT count(*) AS count, cloud_platform FROM unnested_platforms
  GROUP BY cloud_platform
""").fetchdf()

results.groupby(['cloud_platform']).sum().plot.pie(y="count", legend=None)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## What services have the most vulnerabilities?
#
# Let's do the same thing with the services.

# %%
results=conn.execute("""
  WITH unnested_services AS (
    SELECT UNNEST(affectedServices) AS services
    FROM vulns)
  SELECT count(*) AS count, services FROM unnested_services
  GROUP BY services
  ORDER BY services ASC
""").fetchdf()

results.groupby(['services']).sum().plot.bar(y="count", figsize=(18, 5))
# Out:
# <Axes: xlabel='services'>
